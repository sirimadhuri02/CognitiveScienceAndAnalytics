# %% [markdown]
# <a href="https://colab.research.google.com/github/sirimadhuri02/CognitiveScienceAndAnalytics/blob/StemmingandLemmatization/Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
text = "The researchers were studying various running and swimming techniques."

# %%
ps = PorterStemmer()

# %%
words = word_tokenize(text)

# %%
stemmed_words = [ps.stem(word) for word in words]
print("Original Words:", words)
print("Stemmed Words:", stemmed_words)
# Out:
# Original Words: ['The', 'researchers', 'were', 'studying', 'various', 'running', 'and', 'swimming', 'techniques', '.']
# Stemmed Words: ['the', 'research', 'were', 'studi', 'variou', 'run', 'and', 'swim', 'techniqu', '.']

# %%
text2 = "I am Siri Madhuri, This is cognitive lab task1 , we have been working on' this project for a while."
words2 = word_tokenize(text2)
stemmed_words = [ps.stem(word) for word in words]
print("Original Words:", words2)
print("Stemmed Words:", stemmed_words)
# Out:
# Original Words: ['I', 'am', 'Siri', 'Madhuri', ',', 'This', 'is', 'cognitive', 'lab', 'task1', ',', 'we', 'have', 'been', 'working', 'on', "'", 'this', 'project', 'for', 'a', 'while', '.']
# Stemmed Words: ['the', 'research', 'were', 'studi', 'variou', 'run', 'and', 'swim', 'techniqu', '.']

# %%
from nltk.stem import LancasterStemmer
ls = LancasterStemmer()
stemmed_lancaster = [ls.stem(word) for word in words2]
print("Lancaster Stemmer Output:", stemmed_lancaster)
# Out:
# Lancaster Stemmer Output: ['i', 'am', 'sir', 'madhur', ',', 'thi', 'is', 'cognit', 'lab', 'task1', ',', 'we', 'hav', 'been', 'work', 'on', "'", 'thi', 'project', 'for', 'a', 'whil', '.']
